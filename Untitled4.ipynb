# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavikhedkar2002/PRODIGY_GA_2/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 ! pip install min_dalle -q
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 13.8 MB/s eta 0:00:00
# ...

# %%
from min_dalle import MinDalle
model = MinDalle(is_mega=True, is_reusable=True)
# Out:
# using device cuda
# downloading tokenizer params
# intializing TextTokenizer
# downloading encoder params
# initializing DalleBartEncoder
# ...

# %%
text = "A vibrant sunset over the city skyline with silhouetted buildings"
seed = 6
grid_size = 2
display(model.generate_image(text, seed, grid_size))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
